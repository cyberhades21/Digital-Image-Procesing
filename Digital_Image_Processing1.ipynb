# %% [markdown]
# <a href="https://colab.research.google.com/github/cyberhades21/Digital-Image-Procesing/blob/Basic/Digital_Image_Processing1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2
from PIL import Image,ImageEnhance
from google.colab.patches import cv2_imshow as CV1

# %%
image1=Image.open("itachi.png")

# %%
display(image1)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=1920x1080 at 0x7F9EE2D87050>

# %%
print(image1.size)
# Out:
# (1920, 1080)

# %%
display(image1.rotate(45))
# Out:
# <PIL.Image.Image image mode=P size=1920x1080 at 0x7F9EE2D24BD0>

# %%
dim=(0,0,1000,1000)
cropped=image1.crop(dim)
display(cropped)
# Out:
# <PIL.Image.Image image mode=P size=1000x1000 at 0x7F9EE2D870D0>

# %%
grayscaled=image1.convert('L')
display(grayscaled)
# Out:
# <PIL.Image.Image image mode=L size=1920x1080 at 0x7F9EE2D39110>

# %%
import numpy as np
from cv2 import cv2
img = cv2.imread( "Lenna.bmp", -1 )
ROI_x, ROI_y = eval( input( "Enter (x, y) for ROI: " ) )
ROI_nr, ROI_nc = eval( input( "Enter (rows, columns) for ROI: " ) )
ROI = img[ ROI_x : ROI_x + ROI_nr, ROI_y : ROI_y + ROI_nc ]
cv2.imshow( "ROI", ROI )
cv2.waitKey(0)
cv2.imshow( "Example", img )
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Enter (x, y) for ROI: 100,200
# Enter (rows, columns) for ROI: 500,600
